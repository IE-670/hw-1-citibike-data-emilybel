# %% [markdown]
# Emily Belote
#
# -Static assignments not included, everything else working

# %% [markdown]
# # Citi Bike Data
# - https://www.citibikenyc.com/system-data
#
# This Jupyter notebook does the following (as of Monday, Feb. 17):
# 1. Imports .json data of Station Info (consider to be static)
# 2. Imports .json data of Station Status (may change frequently)
# 3. Imports .csv of Citi Bike trips
#
#
# - We'll use the Station Info/Status data to build a VeRoViz "nodes" dataframe.
# - We'll use the trips data to build a VeRoViz "assignments" dataframe.
#
# With the nodes and assignments dataframes, we can then generate Leaflet maps (static) and Cesium movies.
#
# ---

# %%
# We'll need these libraries
import numpy as np
import pandas as pd

# %%
# These libraries will help us import JSON data:
import json
import urllib.request

# %%
# Go ahead and import VeRoViz
import veroviz as vrv
vrv.checkVersion()
# Out:
# 'Your current installed version of veroviz is 0.3.1. You are up-to-date with the latest available version.'

# %%
# I like to use "environment" variables to store "private" stuff
# (like API keys, or paths to installed files).
# We'll need the `os` library for that:
import os

# See https://veroviz.org/documentation.html#installation for details

# %% [markdown]
# ---
#
# ## 1. Import Station Info (from .json)
# - These data are *mostly* static...certainly won't change throughout the course of a day.

# %%
# Tim's approach for grabbing JSON data:
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_information.json") as url:
    station_info_data = json.loads(url.read().decode())
station_info_data
# Out:
# {'last_updated': 1582826464,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '304',
#     'external_id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & Battery Pl',
#     'short_name': '4962.01',
#     'lat': 40.70463334,
#     'lon': -74.01361706,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=304',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'eightd_station_services': [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a',
#       'service_type': 'ATTENDED_SERVICE',
#       'bikes_availability': 'UNLIMITED',
#       'docks_availability': 'NONE',
#       'name': 'Valet Service',
#       'description': 'Citi Bike Valet Attendant Service Available',
#       'schedule_description': '',
#       'link_for_more_info': 'https://www.citibikenyc.com/valet'}],
#     'has_kiosk': True},
#    {'station_id': '367',
#     'external_id': '66dbcdfc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 53 St & Lexington Ave',
#     'short_name': '6617.09',
#     'lat': 40.75828065,
#     'lon': -73.97069431,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 34,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=367',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'eightd_station_services': [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0',
#       'service_type': 'ATTENDED_SERVICE',
#       'bikes_availability': 'UNLIMITED',
#       'docks_availability': 'NONE',
#       'name': 'Valet Service',
#       'description': 'Citi Bike Valet Attendant Service Available',
#       'schedule_description': '',
#       'link_for_more_info': 'https://www.citibikenyc.com/valet'}],
#     'has_kiosk': True},
#    {'station_id': '402',
#     'external_id': '66dbf0d0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & E 22 St',
#     'short_name': '6098.07',
#     'lat': 40.7403432,
#     'lon': -73.98955109,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=402',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'eightd_station_services': [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981',
#       'service_type': 'ATTENDED_SERVICE',
#       'bikes_availability': 'UNLIMITED',
#       'docks_availability': 'NONE',
#       'name': 'Valet Service',
#       'description': 'Citi Bike Valet Attendant Service Available',
#       'schedule_description': '',
#       'link_for_more_info': 'https://www.citibikenyc.com/valet'}],
#     'has_kiosk': True},
#    {'station_id': '3443',
#     'external_id': '66de8a86-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 52 St & 6 Ave',
#     'short_name': '6740.01',
#     'lat': 40.76132983124814,
#     'lon': -73.97982001304626,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3443',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'eightd_station_services': [{'id': '286d75b2-088f-4a79-bf7d-223928be711c',
#       'service_type': 'ATTENDED_SERVICE',
#       'bikes_availability': 'UNLIMITED',
#       'docks_availability': 'NONE',
#       'name': 'Valet Service',
#       'description': 'Citi Bike Valet station attendant service available',
#       'schedule_description': '',
#       'link_for_more_info': 'https://www.citibikenyc.com/valet'}],
#     'has_kiosk': True},
#    {'station_id': '72',
#     'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 52 St & 11 Ave',
#     'short_name': '6926.01',
#     'lat': 40.76727216,
#     'lon': -73.99392888,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=72',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '79',
#     'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Franklin St & W Broadway',
#     'short_name': '5430.08',
#     'lat': 40.71911552,
#     'lon': -74.00666661,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=79',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '82',
#     'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Pearl St',
#     'short_name': '5167.06',
#     'lat': 40.71117416,
#     'lon': -74.00016545,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=82',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '83',
#     'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Atlantic Ave & Fort Greene Pl',
#     'short_name': '4354.07',
#     'lat': 40.68382604,
#     'lon': -73.97632328,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 62,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=83',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '116',
#     'external_id': '66db28b5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 17 St & 8 Ave',
#     'short_name': '6148.02',
#     'lat': 40.74177603,
#     'lon': -74.00149746,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 50,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=116',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '119',
#     'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Park Ave & St Edwards St',
#     'short_name': '4700.06',
#     'lat': 40.69608941,
#     'lon': -73.97803415,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=119',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '120',
#     'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lexington Ave & Classon Ave',
#     'short_name': '4452.03',
#     'lat': 40.68676793,
#     'lon': -73.95928168,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=120',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '127',
#     'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Barrow St & Hudson St',
#     'short_name': '5805.05',
#     'lat': 40.73172428,
#     'lon': -74.00674436,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=127',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '128',
#     'external_id': '66db2afe-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Prince St',
#     'short_name': '5687.04',
#     'lat': 40.72710258,
#     'lon': -74.00297088,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=128',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '143',
#     'external_id': '66db2d2b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Clinton St & Joralemon St',
#     'short_name': '4605.04',
#     'lat': 40.69239502,
#     'lon': -73.99337909,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=143',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '144',
#     'external_id': '66db2db5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Nassau St & Navy St',
#     'short_name': '4812.02',
#     'lat': 40.69839895,
#     'lon': -73.98068914,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 58,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=144',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '146',
#     'external_id': '66db2e3a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Hudson St & Reade St',
#     'short_name': '5359.10',
#     'lat': 40.71625008,
#     'lon': -74.0091059,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=146',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '150',
#     'external_id': '66db2f4c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue C',
#     'short_name': '5476.03',
#     'lat': 40.7208736,
#     'lon': -73.98085795,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=150',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '151',
#     'external_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cleveland Pl & Spring St',
#     'short_name': '5492.05',
#     'lat': 40.722103786686034,
#     'lon': -73.99724900722504,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=151',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '157',
#     'external_id': '66db316a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Henry St & Atlantic Ave',
#     'short_name': '4531.05',
#     'lat': 40.69089272,
#     'lon': -73.99612349,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=157',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '161',
#     'external_id': '66db3273-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'LaGuardia Pl & W 3 St',
#     'short_name': '5721.14',
#     'lat': 40.72917025,
#     'lon': -73.99810231,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=161',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '164',
#     'external_id': '66db32fb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 47 St & 2 Ave',
#     'short_name': '6498.10',
#     'lat': 40.75323098,
#     'lon': -73.97032517,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=164',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '167',
#     'external_id': '66db337f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 39 St & 3 Ave',
#     'short_name': '6389.03',
#     'lat': 40.7489006,
#     'lon': -73.97604882,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=167',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '168',
#     'external_id': '66db33fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 18 St & 6 Ave',
#     'short_name': '6064.08',
#     'lat': 40.73971301,
#     'lon': -73.99456405,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=168',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '173',
#     'external_id': '66db347b-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 49 St',
#     'short_name': '6708.02',
#     'lat': 40.76068327096592,
#     'lon': -73.9845272898674,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 70,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=173',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '174',
#     'external_id': '66db34fc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 25 St & 1 Ave',
#     'short_name': '6004.07',
#     'lat': 40.7381765,
#     'lon': -73.97738662,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=174',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '195',
#     'external_id': '66db3583-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Liberty St & Broadway',
#     'short_name': '5105.01',
#     'lat': 40.70905623,
#     'lon': -74.01043382,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=195',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '212',
#     'external_id': '66db3606-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 16 St & The High Line',
#     'short_name': '6233.05',
#     'lat': 40.74334935,
#     'lon': -74.00681753,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 60,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=212',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '216',
#     'external_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Columbia Heights & Cranberry St',
#     'short_name': '4829.01',
#     'lat': 40.70037867,
#     'lon': -73.99548059,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=216',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '217',
#     'external_id': '66db3708-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Old Fulton St',
#     'short_name': '4903.08',
#     'lat': 40.70277159,
#     'lon': -73.99383605,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=217',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '223',
#     'external_id': '66db3816-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 13 St & 7 Ave',
#     'short_name': '6030.04',
#     'lat': 40.73781509,
#     'lon': -73.99994661,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=223',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '224',
#     'external_id': '66db3898-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Spruce St & Nassau St',
#     'short_name': '5137.10',
#     'lat': 40.71146364,
#     'lon': -74.00552427,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=224',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '228',
#     'external_id': '66db3997-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 48 St & 3 Ave',
#     'short_name': '6541.03',
#     'lat': 40.7546011026,
#     'lon': -73.971878855,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=228',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '229',
#     'external_id': '66db3a1e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Great Jones St',
#     'short_name': '5636.11',
#     'lat': 40.72743423,
#     'lon': -73.99379025,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=229',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '236',
#     'external_id': '66db3ba0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St Marks Pl & 2 Ave',
#     'short_name': '5669.10',
#     'lat': 40.7284186,
#     'lon': -73.98713956,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 47,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=236',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '237',
#     'external_id': '66db3c29-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 2 Ave',
#     'short_name': '5746.04',
#     'lat': 40.73047309,
#     'lon': -73.98672378,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=237',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '238',
#     'external_id': '66db3cab-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Bank St & Washington St',
#     'short_name': '5964.01',
#     'lat': 40.7361967,
#     'lon': -74.00859207,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=238',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '239',
#     'external_id': '66db3d2a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby St & Fleet St',
#     'short_name': '4628.05',
#     'lat': 40.69196566,
#     'lon': -73.9813018,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=239',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '241',
#     'external_id': '66db3da9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & S Portland Ave',
#     'short_name': '4546.04',
#     'lat': 40.68981035,
#     'lon': -73.97493121,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=241',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '242',
#     'external_id': '66db3e32-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Carlton Ave & Flushing Ave',
#     'short_name': '4732.08',
#     'lat': 40.697787,
#     'lon': -73.973736,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 46,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=242',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '244',
#     'external_id': '66db3f01-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Willoughby Ave & Hall St',
#     'short_name': '4611.03',
#     'lat': 40.69196035,
#     'lon': -73.96536851,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=244',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '245',
#     'external_id': '66db3f62-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Myrtle Ave & St Edwards St',
#     'short_name': '4659.02',
#     'lat': 40.69327018,
#     'lon': -73.97703874,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=245',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '247',
#     'external_id': '66db3fc9-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Perry St & Bleecker St',
#     'short_name': '5922.07',
#     'lat': 40.73535398,
#     'lon': -74.00483091,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=247',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '248',
#     'external_id': '66db402c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Laight St & Hudson St',
#     'short_name': '5539.06',
#     'lat': 40.72185379,
#     'lon': -74.00771779,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=248',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '249',
#     'external_id': '66db408f-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Harrison St & Hudson St',
#     'short_name': '5400.05',
#     'lat': 40.71870987,
#     'lon': -74.0090009,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=249',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '250',
#     'external_id': '66db40ef-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette St & Jersey St',
#     'short_name': '5561.06',
#     'lat': 40.72456089,
#     'lon': -73.99565293,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 40,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=250',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '251',
#     'external_id': '66db4158-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mott St & Prince St',
#     'short_name': '5561.04',
#     'lat': 40.72317958,
#     'lon': -73.99480012,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=251',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '252',
#     'external_id': '66db41bf-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'MacDougal St & Washington Sq',
#     'short_name': '5797.01',
#     'lat': 40.73226398,
#     'lon': -73.99852205,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=252',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '254',
#     'external_id': '66db4282-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'W 11 St & 6 Ave',
#     'short_name': '5914.03',
#     'lat': 40.73532427,
#     'lon': -73.99800419,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 59,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=254',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '257',
#     'external_id': '66db4351-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lispenard St & Broadway',
#     'short_name': '5391.06',
#     'lat': 40.71939226,
#     'lon': -74.00247214,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=257',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '258',
#     'external_id': '66db43b5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Vanderbilt Ave',
#     'short_name': '4461.04',
#     'lat': 40.68940747,
#     'lon': -73.96885458,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=258',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '259',
#     'external_id': '66db4417-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Whitehall St',
#     'short_name': '4846.01',
#     'lat': 40.70122128,
#     'lon': -74.01234218,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=259',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '260',
#     'external_id': '66db447a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broad St & Bridge St',
#     'short_name': '4962.08',
#     'lat': 40.70365182,
#     'lon': -74.01167797,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=260',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '261',
#     'external_id': '66db44e5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Johnson St & Gold St',
#     'short_name': '4668.08',
#     'lat': 40.69474881,
#     'lon': -73.98362464,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=261',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '262',
#     'external_id': '66db4549-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Park',
#     'short_name': '4546.05',
#     'lat': 40.6917823,
#     'lon': -73.9737299,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=262',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '264',
#     'external_id': '66db460d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Maiden Ln & Pearl St',
#     'short_name': '5065.10',
#     'lat': 40.70706456,
#     'lon': -74.00731853,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=264',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '265',
#     'external_id': '66db4671-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Stanton St & Chrystie St',
#     'short_name': '5523.02',
#     'lat': 40.72229346,
#     'lon': -73.99147535,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=265',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '267',
#     'external_id': '66db473c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & W 36 St',
#     'short_name': '6441.01',
#     'lat': 40.75097711,
#     'lon': -73.98765428,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 78,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=267',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '268',
#     'external_id': '66db479e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Howard St & Centre St',
#     'short_name': '5422.04',
#     'lat': 40.71910537,
#     'lon': -73.99973337,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=268',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '270',
#     'external_id': '66db5c14-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Adelphi St & Myrtle Ave',
#     'short_name': '4620.02',
#     'lat': 40.69308257,
#     'lon': -73.97178913,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=270',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '274',
#     'external_id': '66db5d28-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette Ave & Fort Greene Pl',
#     'short_name': '4395.04',
#     'lat': 40.68691865,
#     'lon': -73.976682,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=274',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '275',
#     'external_id': '66db5d92-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Greene Ave',
#     'short_name': '4419.03',
#     'lat': 40.68650065,
#     'lon': -73.96563307,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=275',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '276',
#     'external_id': '66db5dfb-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Duane St & Greenwich St',
#     'short_name': '5400.08',
#     'lat': 40.71748752,
#     'lon': -74.0104554,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=276',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '278',
#     'external_id': '66db5e6a-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Concord St & Bridge St',
#     'short_name': '4781.03',
#     'lat': 40.69766564,
#     'lon': -73.98476437,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=278',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '280',
#     'external_id': '66db5f40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 10 St & 5 Ave',
#     'short_name': '5872.08',
#     'lat': 40.73331967,
#     'lon': -73.99510132,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 59,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=280',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '281',
#     'external_id': '66db5fae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Grand Army Plaza & Central Park S',
#     'short_name': '6839.10',
#     'lat': 40.7643971,
#     'lon': -73.97371465,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 66,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=281',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '282',
#     'external_id': '66db6299-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Kent Ave & S 11 St',
#     'short_name': '5062.01',
#     'lat': 40.707644944175705,
#     'lon': -73.96841526031494,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=282',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '284',
#     'external_id': '66db631c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Greenwich Ave & 8 Ave',
#     'short_name': '6072.06',
#     'lat': 40.7390169121,
#     'lon': -74.0026376103,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=284',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '285',
#     'external_id': '66db6387-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Broadway & E 14 St',
#     'short_name': '5905.12',
#     'lat': 40.73454567,
#     'lon': -73.99074142,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 53,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=285',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '289',
#     'external_id': '66db63f4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Monroe St & Classon Ave',
#     'short_name': '4336.01',
#     'lat': 40.6845683,
#     'lon': -73.95881081,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=289',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '291',
#     'external_id': '66db64d1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Madison St & Montgomery St',
#     'short_name': '5262.09',
#     'lat': 40.713126,
#     'lon': -73.984844,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=291',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '293',
#     'external_id': '66db65aa-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lafayette St & E 8 St',
#     'short_name': '5788.13',
#     'lat': 40.73020660529954,
#     'lon': -73.99102628231049,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 55,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=293',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '295',
#     'external_id': '66db6889-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Pike St & E Broadway',
#     'short_name': '5270.05',
#     'lat': 40.71406667,
#     'lon': -73.99293911,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 24,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=295',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '297',
#     'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 15 St & 3 Ave',
#     'short_name': '5863.07',
#     'lat': 40.734232,
#     'lon': -73.986923,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=297',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '298',
#     'external_id': '66db69d0-0aca-11e7-82f6-3863bb44ef7c',
#     'name': '3 Ave & Schermerhorn St',
#     'short_name': '4437.01',
#     'lat': 40.68683208,
#     'lon': -73.9796772,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=298',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '301',
#     'external_id': '66db6aae-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 2 St & Avenue B',
#     'short_name': '5515.02',
#     'lat': 40.72217444,
#     'lon': -73.98368779,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 58,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=301',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '302',
#     'external_id': '66db6cd4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Avenue D & E 3 St',
#     'short_name': '5436.09',
#     'lat': 40.72082834,
#     'lon': -73.97793172,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=302',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '303',
#     'external_id': '66db6d40-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Mercer St & Spring St',
#     'short_name': '5532.01',
#     'lat': 40.72362738,
#     'lon': -73.99949601,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 67,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=303',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '305',
#     'external_id': '66db6e49-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 58 St & 3 Ave',
#     'short_name': '6762.02',
#     'lat': 40.76095756,
#     'lon': -73.96724467,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=305',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '307',
#     'external_id': '66db6f2e-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Canal St & Rutgers St',
#     'short_name': '5303.08',
#     'lat': 40.71427487,
#     'lon': -73.98990025,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=307',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '308',
#     'external_id': '66db7152-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'St James Pl & Oliver St',
#     'short_name': '5238.05',
#     'lat': 40.71307916,
#     'lon': -73.99851193,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=308',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '309',
#     'external_id': '66db71be-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Murray St & West St',
#     'short_name': '5329.06',
#     'lat': 40.7149787,
#     'lon': -74.013012,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=309',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '310',
#     'external_id': '66db7221-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'State St & Smith St',
#     'short_name': '4565.06',
#     'lat': 40.68926942,
#     'lon': -73.98912867,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 36,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=310',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '311',
#     'external_id': '66db728c-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Norfolk St & Broome St',
#     'short_name': '5374.01',
#     'lat': 40.7172274,
#     'lon': -73.98802084,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=311',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '312',
#     'external_id': '66db72f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Allen St & Stanton St',
#     'short_name': '5484.09',
#     'lat': 40.722055,
#     'lon': -73.989111,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=312',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '313',
#     'external_id': '66db74a5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Washington Ave & Park Ave',
#     'short_name': '4724.03',
#     'lat': 40.69610226,
#     'lon': -73.96751037,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=313',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '315',
#     'external_id': '66db75cc-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'South St & Gouverneur Ln',
#     'short_name': '4953.04',
#     'lat': 40.70355377,
#     'lon': -74.00670227,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 29,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=315',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '316',
#     'external_id': '66db7637-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & William St',
#     'short_name': '5137.11',
#     'lat': 40.70955958,
#     'lon': -74.00653609,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 43,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=316',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '317',
#     'external_id': '66db76a1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 6 St & Avenue B',
#     'short_name': '5584.04',
#     'lat': 40.72453734,
#     'lon': -73.98185424,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 54,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=317',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '319',
#     'external_id': '66db79a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Fulton St & Broadway',
#     'short_name': '5175.08',
#     'lat': 40.711066,
#     'lon': -74.009447,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 33,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=319',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '320',
#     'external_id': '66db7a0d-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Leonard St & Church St',
#     'short_name': '5359.11',
#     'lat': 40.717571,
#     'lon': -74.005549,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=320',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '321',
#     'external_id': '66db7a71-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Cadman Plaza E & Red Cross Pl',
#     'short_name': '4821.06',
#     'lat': 40.69991755,
#     'lon': -73.98971773,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=321',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '323',
#     'external_id': '66db88f5-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Lawrence St & Willoughby St',
#     'short_name': '4596.09',
#     'lat': 40.69236178,
#     'lon': -73.98631746,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=323',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '324',
#     'external_id': '66db89a3-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'DeKalb Ave & Hudson Ave',
#     'short_name': '4513.06',
#     'lat': 40.689888,
#     'lon': -73.981013,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 51,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=324',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '325',
#     'external_id': '66db8c10-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 19 St & 3 Ave',
#     'short_name': '5938.01',
#     'lat': 40.73624527,
#     'lon': -73.98473765,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 35,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=325',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '326',
#     'external_id': '66db8ca4-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'E 11 St & 1 Ave',
#     'short_name': '5746.14',
#     'lat': 40.72953837,
#     'lon': -73.98426726,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 41,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=326',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '327',
#     'external_id': '66db8d89-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Vesey Pl & River Terrace',
#     'short_name': '5297.02',
#     'lat': 40.7153379,
#     'lon': -74.01658354,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=327',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '328',
#     'external_id': '66db8fde-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Watts St & Greenwich St',
#     'short_name': '5578.02',
#     'lat': 40.72405549,
#     'lon': -74.00965965,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=328',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '330',
#     'external_id': '66db90f1-0aca-11e7-82f6-3863bb44ef7c',
#     'name': 'Reade St & Broadway',
#     'short_name': '5247.10',
#     'lat': 40.71450451,
#     'lon': -74.00562789,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=330',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '331',
# ...
#     'external_id': 'a6a132f9-89bf-42a4-afe6-1ca449b7f570',
#     'name': 'Cypress Ave & George St',
#     'short_name': '4765.07',
#     'lat': 40.69812,
#     'lon': -73.90271,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3878',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3879',
#     'external_id': '679dcf08-d88c-4d1b-b81d-fe9f4aabbff7',
#     'name': 'Broadway & Madison St',
#     'short_name': '4483.10',
#     'lat': 40.68822,
#     'lon': -73.91966,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3879',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3880',
#     'external_id': 'ee1ba75f-baf5-4852-929c-8b7ad310f55a',
#     'name': 'Willoughby Ave & Onderdonk Ave',
#     'short_name': '5115.05',
#     'lat': 40.7098,
#     'lon': -73.91727,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3880',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3881',
#     'external_id': 'eab2749b-2f79-4797-a0a6-0579b27e6929',
#     'name': '12 Ave & W 125 St',
#     'short_name': '7886.02',
#     'lat': 40.818299,
#     'lon': -73.960405,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3881',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3882',
#     'external_id': '141ba25c-f4ea-4cec-ae7e-022401e23087',
#     'name': 'Norman St & Wyckoff Ave',
#     'short_name': '4654.01',
#     'lat': 40.69517,
#     'lon': -73.90311,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 15,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3882',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3883',
#     'external_id': 'a3e2b360-f050-48ea-b8c8-57d897b8f7fc',
#     'name': 'Harman St & Seneca Ave',
#     'short_name': '5002.09',
#     'lat': 40.70577,
#     'lon': -73.91292,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3883',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3884',
#     'external_id': 'a7c09fde-76e8-4a56-b61d-8ca940432efd',
#     'name': 'Centre St & Seneca Ave',
#     'short_name': '4837.03',
#     'lat': 40.69969,
#     'lon': -73.9022,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 23,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3884',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3885',
#     'external_id': '1057229c-f8f8-4014-80cd-f40421c61cf0',
#     'name': 'Onderdonk Ave & Gates Ave',
#     'short_name': '4994.10',
#     'lat': 40.70413,
#     'lon': -73.90737,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3885',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3886',
#     'external_id': '8f3a6711-fd05-4ce1-acf8-9d72b4a1bf97',
#     'name': 'Menahan St & Onderdonk Ave',
#     'short_name': '5034.03',
#     'lat': 40.70553,
#     'lon': -73.9096,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3886',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3887',
#     'external_id': 'd89dc10f-9be3-45a5-9c3c-06c04c963436',
#     'name': 'Flushing Ave & Woodward Ave',
#     'short_name': '5225.02',
#     'lat': 40.71246,
#     'lon': -73.91873,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 21,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3887',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3888',
#     'external_id': '55a4dc76-d839-4e06-9bf4-2f343391343c',
#     'name': 'Woodward Ave & Harman St',
#     'short_name': '5074.08',
#     'lat': 40.70793,
#     'lon': -73.91092,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3888',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3890',
#     'external_id': 'ad57266c-34da-43da-8b48-2ba856002fbf',
#     'name': 'Grove St & Broadway',
#     'short_name': '4526.01',
#     'lat': 40.69047,
#     'lon': -73.923511,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3890',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3891',
#     'external_id': 'b35ba3c0-d3e8-4b1a-b63b-73a7bb518c9e',
#     'name': 'Irving Ave & Palmetto St',
#     'short_name': '4775.01',
#     'lat': 40.698,
#     'lon': -73.9127,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3891',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3892',
#     'external_id': 'ad41e353-033e-484f-8d76-78014e11e9d7',
#     'name': '38 Ave & 29 St',
#     'short_name': '6538.11',
#     'lat': 40.75473,
#     'lon': -73.93367,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3892',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3893',
#     'external_id': '59e3766c-0629-4ff1-a1d9-bc0514a55487',
#     'name': 'Rockaway Ave & Bainbridge St',
#     'short_name': '4285.09',
#     'lat': 40.68319988172761,
#     'lon': -73.91166642308235,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3893',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3895',
#     'external_id': '87091002-cc25-452a-b5d9-f8d0c3fce422',
#     'name': 'Cypress Ave & Palmetto St',
#     'short_name': '4921.04',
#     'lat': 40.701573408737914,
#     'lon': -73.90876293182373,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 25,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3895',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3896',
#     'external_id': '26cae473-0e59-4af7-bad5-bb6fec85c8bc',
#     'name': 'Madison St & Seneca Ave',
#     'short_name': '4880.11',
#     'lat': 40.70183,
#     'lon': -73.90625,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 22,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3896',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3897',
#     'external_id': 'be8e6f1c-e8b5-40bd-896d-423052ba3bbc',
#     'name': 'Onderdonk Ave & Dekalb Ave',
#     'short_name': '5115.01',
#     'lat': 40.70863,
#     'lon': -73.91497,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3897',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3898',
#     'external_id': '199ea9dd-8f7e-4e05-a730-55edaacd8787',
#     'name': 'E 63 St & 3 Ave',
#     'short_name': '6830.02',
#     'lat': 40.763954,
#     'lon': -73.9646,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 57,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3898',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3899',
#     'external_id': 'bd30f2a1-38ec-474d-9e36-07f688e87427',
#     'name': 'Manhattan Av & Leonard St',
#     'short_name': '5442.09',
#     'lat': 40.72084,
#     'lon': -73.94844,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 18,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3899',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3900',
#     'external_id': '344064f8-e82f-40fb-b235-aff506b77ae5',
#     'name': 'Morgan Ave & Lombardy St',
#     'short_name': '5503.01',
#     'lat': 40.72226,
#     'lon': -73.93889,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3900',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3901',
#     'external_id': '837b7db3-55c6-4595-a497-834972631752',
#     'name': 'Stanhope St & Fairview Ave',
#     'short_name': '5146.03',
#     'lat': 40.70998,
#     'lon': -73.91116,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3901',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3902',
#     'external_id': '1abd4668-ed6b-4930-8177-17239ae75a9e',
#     'name': 'Fairview Ave & Linden St',
#     'short_name': '5066.03',
#     'lat': 40.70694,
#     'lon': -73.90632,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3902',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3903',
#     'external_id': '88ee054e-bdeb-4305-8f3b-76eb964f2c84',
#     'name': 'Jefferson Ave & Evergreen Ave',
#     'short_name': '4517.03',
#     'lat': 40.68989,
#     'lon': -73.91458,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3903',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3905',
#     'external_id': '0f45bcf6-7028-4584-a51e-4129847dbebc',
#     'name': '4 Ave & E 12 St',
#     'short_name': '5788.15',
#     'lat': 40.732647,
#     'lon': -73.99011,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 27,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3905',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3907',
#     'external_id': '75352ab4-8a31-4926-8b59-048a9e506452',
#     'name': 'Central Ave & Melrose St',
#     'short_name': '4832.07',
#     'lat': 40.70112,
#     'lon': -73.93039,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3907',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3909',
#     'external_id': '16836c76-c412-4ec3-bac8-3c6a5a3d9745',
#     'name': 'Madison St & Woodward Ave',
#     'short_name': '4954.07',
#     'lat': 40.70408,
#     'lon': -73.90408,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 20,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3909',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3910',
#     'external_id': '30985a9c-afe4-4b98-a72c-2c72bb35603e',
#     'name': 'Greene Ave & Grandview Ave',
#     'short_name': '5106.04',
#     'lat': 40.709697,
#     'lon': -73.907856,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 17,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3910',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3911',
#     'external_id': '8d553914-6de8-428c-b620-d3c5d66bbb45',
#     'name': 'Wyckoff St & Nevins St',
#     'short_name': '4290.08',
#     'lat': 40.683426,
#     'lon': -73.984275,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 22,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3911',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3913',
#     'external_id': '8dfff4bd-0f3c-43af-bc55-a63850f66c6b',
#     'name': 'Sands St Gate',
#     'short_name': '4812.04',
#     'lat': 40.699569,
#     'lon': -73.979827,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 19,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3913',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3914',
#     'external_id': '8bab3ee9-1302-46a0-b755-f21a2ff4e7ba',
#     'name': 'West End Ave & W 78 St',
#     'short_name': '7340.07',
#     'lat': 40.783786,
#     'lon': -73.981687,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 39,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3914',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3916',
#     'external_id': '8deeaea2-aa12-4925-9ee0-5f9bd0cde7e6',
#     'name': 'Pearl St & Peck Slip',
#     'short_name': '5096.11',
#     'lat': 40.708485,
#     'lon': -74.002751,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 45,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3916',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': True,
#     'has_kiosk': True},
#    {'station_id': '3917',
#     'external_id': '582cd775-0178-47f5-b707-6d5869f077ba',
#     'name': 'Willoughby St & Ashland Pl',
#     'short_name': '4587.02',
#     'lat': 40.69178,
#     'lon': -73.97877,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 31,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3917',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True},
#    {'station_id': '3918',
#     'external_id': '2d086235-2516-4aa0-a6c1-0ba3b03b6ec6',
#     'name': 'Avenue D & E 8 St',
#     'short_name': '5575.12',
#     'lat': 40.72387,
#     'lon': -73.975767,
#     'region_id': 71,
#     'rental_methods': ['CREDITCARD', 'KEY'],
#     'capacity': 30,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3918',
#     'electric_bike_surcharge_waiver': False,
#     'eightd_has_key_dispenser': False,
#     'has_kiosk': True}]}}

# %%
# Convert the JSON data into a Pandas dataframe:
station_info_df = pd.DataFrame(station_info_data['data']['stations'])
station_info_df.head()
# Out:
#   station_id                           external_id                     name  \
# 0        304  66db6da2-0aca-11e7-82f6-3863bb44ef7c    Broadway & Battery Pl
# 1        367  66dbcdfc-0aca-11e7-82f6-3863bb44ef7c  E 53 St & Lexington Ave
# 2        402  66dbf0d0-0aca-11e7-82f6-3863bb44ef7c       Broadway & E 22 St
# 3       3443  66de8a86-0aca-11e7-82f6-3863bb44ef7c          W 52 St & 6 Ave
# 4         72  66db237e-0aca-11e7-82f6-3863bb44ef7c         W 52 St & 11 Ave
#
#   short_name        lat        lon  region_id     rental_methods  capacity  \
# 0    4962.01  40.704633 -74.013617         71  [CREDITCARD, KEY]        33
# 1    6617.09  40.758281 -73.970694         71  [CREDITCARD, KEY]        34
# 2    6098.07  40.740343 -73.989551         71  [CREDITCARD, KEY]        39
# 3    6740.01  40.761330 -73.979820         71  [CREDITCARD, KEY]        41
# 4    6926.01  40.767272 -73.993929         71  [CREDITCARD, KEY]        55
#
#                                           rental_url  \
# 0  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 1  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 2  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 3  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
# 4  http://app.citibikenyc.com/S6Lr/IBV092JufD?sta...
#
#    electric_bike_surcharge_waiver  eightd_has_key_dispenser  \
# 0                           False                      True
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
#
#                              eightd_station_services  has_kiosk
# 0  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'...       True
# 1  [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'...       True
# 2  [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'...       True
# 3  [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'...       True
# 4                                                NaN       True

# %% [markdown]
# ---
#
# ## 2.  Get Station Status Data (from .json)
# - These data may change frequently.  I don't know how often they're updated.

# %%
# Tim's approach for grabbing JSON data:
with urllib.request.urlopen("https://gbfs.citibikenyc.com/gbfs/en/station_status.json") as url:
    station_status_data = json.loads(url.read().decode())
station_status_data
# Out:
# {'last_updated': 1582826474,
#  'ttl': 10,
#  'data': {'stations': [{'station_id': '304',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 0,
#     'last_reported': 1582825054,
#     'eightd_has_available_keys': True,
#     'eightd_active_station_services': [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]},
#    {'station_id': '367',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 0,
#     'last_reported': 1582826089,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'}]},
#    {'station_id': '402',
#     'num_bikes_available': 10,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 0,
#     'last_reported': 1582826401,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]},
#    {'station_id': '3443',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 37,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 0,
#     'last_reported': 1582826174,
#     'eightd_has_available_keys': False,
#     'eightd_active_station_services': [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'}]},
#    {'station_id': '72',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825850,
#     'eightd_has_available_keys': False},
#    {'station_id': '79',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826169,
#     'eightd_has_available_keys': False},
#    {'station_id': '82',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826215,
#     'eightd_has_available_keys': False},
#    {'station_id': '83',
#     'num_bikes_available': 56,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826474,
#     'eightd_has_available_keys': False},
#    {'station_id': '116',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826381,
#     'eightd_has_available_keys': False},
#    {'station_id': '119',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825907,
#     'eightd_has_available_keys': False},
#    {'station_id': '120',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820653,
#     'eightd_has_available_keys': False},
#    {'station_id': '127',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826095,
#     'eightd_has_available_keys': False},
#    {'station_id': '128',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826064,
#     'eightd_has_available_keys': False},
#    {'station_id': '143',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826317,
#     'eightd_has_available_keys': False},
#    {'station_id': '144',
#     'num_bikes_available': 53,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826409,
#     'eightd_has_available_keys': False},
#    {'station_id': '146',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826372,
#     'eightd_has_available_keys': False},
#    {'station_id': '150',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 51,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825740,
#     'eightd_has_available_keys': False},
#    {'station_id': '151',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826174,
#     'eightd_has_available_keys': True},
#    {'station_id': '157',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823946,
#     'eightd_has_available_keys': False},
#    {'station_id': '161',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826309,
#     'eightd_has_available_keys': False},
#    {'station_id': '164',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826414,
#     'eightd_has_available_keys': False},
#    {'station_id': '167',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826119,
#     'eightd_has_available_keys': False},
#    {'station_id': '168',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826312,
#     'eightd_has_available_keys': False},
#    {'station_id': '173',
#     'num_bikes_available': 53,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826151,
#     'eightd_has_available_keys': False},
#    {'station_id': '174',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826349,
#     'eightd_has_available_keys': False},
#    {'station_id': '195',
#     'num_bikes_available': 42,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826442,
#     'eightd_has_available_keys': False},
#    {'station_id': '212',
#     'num_bikes_available': 59,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825352,
#     'eightd_has_available_keys': False},
#    {'station_id': '216',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824965,
#     'eightd_has_available_keys': False},
#    {'station_id': '217',
#     'num_bikes_available': 38,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825371,
#     'eightd_has_available_keys': True},
#    {'station_id': '223',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826262,
#     'eightd_has_available_keys': False},
#    {'station_id': '224',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826291,
#     'eightd_has_available_keys': True},
#    {'station_id': '228',
#     'num_bikes_available': 51,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826065,
#     'eightd_has_available_keys': False},
#    {'station_id': '229',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826433,
#     'eightd_has_available_keys': False},
#    {'station_id': '236',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826470,
#     'eightd_has_available_keys': False},
#    {'station_id': '237',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 38,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826393,
#     'eightd_has_available_keys': False},
#    {'station_id': '238',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 31,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826252,
#     'eightd_has_available_keys': False},
#    {'station_id': '239',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825191,
#     'eightd_has_available_keys': False},
#    {'station_id': '241',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582821413,
#     'eightd_has_available_keys': False},
#    {'station_id': '242',
#     'num_bikes_available': 44,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825249,
#     'eightd_has_available_keys': False},
#    {'station_id': '244',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824931,
#     'eightd_has_available_keys': False},
#    {'station_id': '245',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826333,
#     'eightd_has_available_keys': True},
#    {'station_id': '247',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 48,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825621,
#     'eightd_has_available_keys': False},
#    {'station_id': '248',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 3,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826362,
#     'eightd_has_available_keys': False},
#    {'station_id': '249',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825117,
#     'eightd_has_available_keys': False},
#    {'station_id': '250',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826466,
#     'eightd_has_available_keys': False},
#    {'station_id': '251',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825109,
#     'eightd_has_available_keys': False},
#    {'station_id': '252',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826139,
#     'eightd_has_available_keys': False},
#    {'station_id': '254',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826105,
#     'eightd_has_available_keys': False},
#    {'station_id': '257',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826170,
#     'eightd_has_available_keys': False},
#    {'station_id': '258',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582819784,
#     'eightd_has_available_keys': False},
#    {'station_id': '259',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826250,
#     'eightd_has_available_keys': True},
#    {'station_id': '260',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825937,
#     'eightd_has_available_keys': False},
#    {'station_id': '261',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825861,
#     'eightd_has_available_keys': False},
#    {'station_id': '262',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824512,
#     'eightd_has_available_keys': False},
#    {'station_id': '264',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825168,
#     'eightd_has_available_keys': False},
#    {'station_id': '265',
#     'num_bikes_available': 15,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826235,
#     'eightd_has_available_keys': False},
#    {'station_id': '267',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 70,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826133,
#     'eightd_has_available_keys': False},
#    {'station_id': '268',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826401,
#     'eightd_has_available_keys': False},
#    {'station_id': '270',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823390,
#     'eightd_has_available_keys': False},
#    {'station_id': '274',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825815,
#     'eightd_has_available_keys': False},
#    {'station_id': '275',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582822868,
#     'eightd_has_available_keys': False},
#    {'station_id': '276',
#     'num_bikes_available': 25,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582822110,
#     'eightd_has_available_keys': False},
#    {'station_id': '278',
#     'num_bikes_available': 12,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824664,
#     'eightd_has_available_keys': False},
#    {'station_id': '280',
#     'num_bikes_available': 57,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826327,
#     'eightd_has_available_keys': False},
#    {'station_id': '281',
#     'num_bikes_available': 59,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826355,
#     'eightd_has_available_keys': False},
#    {'station_id': '282',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825433,
#     'eightd_has_available_keys': False},
#    {'station_id': '284',
#     'num_bikes_available': 8,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826122,
#     'eightd_has_available_keys': False},
#    {'station_id': '285',
#     'num_bikes_available': 32,
#     'num_ebikes_available': 2,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826334,
#     'eightd_has_available_keys': True},
#    {'station_id': '289',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820254,
#     'eightd_has_available_keys': False},
#    {'station_id': '291',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826469,
#     'eightd_has_available_keys': False},
#    {'station_id': '293',
#     'num_bikes_available': 54,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826286,
#     'eightd_has_available_keys': False},
#    {'station_id': '295',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825902,
#     'eightd_has_available_keys': False},
#    {'station_id': '297',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826464,
#     'eightd_has_available_keys': False},
#    {'station_id': '298',
#     'num_bikes_available': 28,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826111,
#     'eightd_has_available_keys': False},
#    {'station_id': '301',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 55,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825987,
#     'eightd_has_available_keys': False},
#    {'station_id': '302',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825081,
#     'eightd_has_available_keys': False},
#    {'station_id': '303',
#     'num_bikes_available': 64,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826378,
#     'eightd_has_available_keys': False},
#    {'station_id': '305',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826214,
#     'eightd_has_available_keys': False},
#    {'station_id': '307',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826270,
#     'eightd_has_available_keys': False},
#    {'station_id': '308',
#     'num_bikes_available': 16,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826136,
#     'eightd_has_available_keys': False},
#    {'station_id': '309',
#     'num_bikes_available': 37,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825886,
#     'eightd_has_available_keys': False},
#    {'station_id': '310',
#     'num_bikes_available': 14,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825298,
#     'eightd_has_available_keys': False},
#    {'station_id': '311',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825947,
#     'eightd_has_available_keys': False},
#    {'station_id': '312',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 28,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826463,
#     'eightd_has_available_keys': False},
#    {'station_id': '313',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826286,
#     'eightd_has_available_keys': False},
#    {'station_id': '315',
#     'num_bikes_available': 26,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823273,
#     'eightd_has_available_keys': True},
#    {'station_id': '316',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825729,
#     'eightd_has_available_keys': False},
#    {'station_id': '317',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 50,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826357,
#     'eightd_has_available_keys': False},
#    {'station_id': '319',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824586,
#     'eightd_has_available_keys': False},
#    {'station_id': '320',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826295,
#     'eightd_has_available_keys': False},
#    {'station_id': '321',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825579,
#     'eightd_has_available_keys': True},
#    {'station_id': '323',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826297,
#     'eightd_has_available_keys': False},
#    {'station_id': '324',
#     'num_bikes_available': 50,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826378,
#     'eightd_has_available_keys': False},
#    {'station_id': '325',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825573,
#     'eightd_has_available_keys': False},
#    {'station_id': '326',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 37,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826298,
#     'eightd_has_available_keys': False},
#    {'station_id': '327',
#     'num_bikes_available': 34,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825759,
#     'eightd_has_available_keys': True},
#    {'station_id': '328',
#     'num_bikes_available': 21,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824772,
#     'eightd_has_available_keys': False},
#    {'station_id': '330',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825290,
#     'eightd_has_available_keys': False},
#    {'station_id': '331',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826068,
#     'eightd_has_available_keys': False},
#    {'station_id': '332',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825376,
#     'eightd_has_available_keys': False},
#    {'station_id': '334',
#     'num_bikes_available': 20,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826301,
#     'eightd_has_available_keys': False},
#    {'station_id': '335',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826306,
#     'eightd_has_available_keys': False},
#    {'station_id': '336',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825708,
#     'eightd_has_available_keys': False},
#    {'station_id': '337',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825841,
#     'eightd_has_available_keys': False},
#    {'station_id': '339',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823806,
#     'eightd_has_available_keys': False},
#    {'station_id': '340',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826269,
#     'eightd_has_available_keys': True},
#    {'station_id': '341',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826034,
#     'eightd_has_available_keys': False},
#    {'station_id': '342',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825400,
#     'eightd_has_available_keys': False},
#    {'station_id': '343',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582815779,
#     'eightd_has_available_keys': False},
#    {'station_id': '344',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823801,
#     'eightd_has_available_keys': False},
#    {'station_id': '346',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825528,
#     'eightd_has_available_keys': False},
#    {'station_id': '347',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826353,
#     'eightd_has_available_keys': False},
#    {'station_id': '349',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 60,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825123,
#     'eightd_has_available_keys': False},
#    {'station_id': '350',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826442,
#     'eightd_has_available_keys': False},
#    {'station_id': '351',
#     'num_bikes_available': 39,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824434,
#     'eightd_has_available_keys': False},
#    {'station_id': '353',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823501,
#     'eightd_has_available_keys': False},
#    {'station_id': '354',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826288,
#     'eightd_has_available_keys': False},
#    {'station_id': '355',
#     'num_bikes_available': 43,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826408,
#     'eightd_has_available_keys': False},
#    {'station_id': '356',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582822926,
#     'eightd_has_available_keys': False},
#    {'station_id': '358',
#     'num_bikes_available': 11,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 39,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826158,
#     'eightd_has_available_keys': False},
#    {'station_id': '359',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 41,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826423,
#     'eightd_has_available_keys': False},
#    {'station_id': '360',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826355,
#     'eightd_has_available_keys': False},
#    {'station_id': '361',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 43,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826471,
#     'eightd_has_available_keys': False},
#    {'station_id': '362',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826102,
#     'eightd_has_available_keys': False},
#    {'station_id': '363',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825740,
#     'eightd_has_available_keys': False},
#    {'station_id': '364',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823790,
#     'eightd_has_available_keys': False},
#    {'station_id': '366',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820685,
#     'eightd_has_available_keys': False},
#    {'station_id': '368',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825794,
#     'eightd_has_available_keys': True},
#    {'station_id': '369',
#     'num_bikes_available': 40,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825285,
#     'eightd_has_available_keys': False},
#    {'station_id': '372',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826453,
#     'eightd_has_available_keys': False},
#    {'station_id': '373',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826301,
#     'eightd_has_available_keys': False},
#    {'station_id': '376',
#     'num_bikes_available': 41,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826473,
#     'eightd_has_available_keys': False},
#    {'station_id': '377',
#     'num_bikes_available': 18,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826369,
#     'eightd_has_available_keys': False},
#    {'station_id': '379',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 37,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826153,
#     'eightd_has_available_keys': False},
#    {'station_id': '380',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826279,
#     'eightd_has_available_keys': False},
#    {'station_id': '383',
#     'num_bikes_available': 13,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825880,
#     'eightd_has_available_keys': False},
#    {'station_id': '385',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826063,
#     'eightd_has_available_keys': False},
#    {'station_id': '386',
#     'num_bikes_available': 35,
#     'num_ebikes_available': 1,
#     'num_bikes_disabled': 3,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826326,
#     'eightd_has_available_keys': False},
#    {'station_id': '387',
#     'num_bikes_available': 36,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 2,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825644,
#     'eightd_has_available_keys': False},
#    {'station_id': '388',
#     'num_bikes_available': 31,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826461,
#     'eightd_has_available_keys': False},
#    {'station_id': '389',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824808,
#     'eightd_has_available_keys': False},
#    {'station_id': '390',
#     'num_bikes_available': 24,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825641,
#     'eightd_has_available_keys': False},
#    {'station_id': '391',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823728,
#     'eightd_has_available_keys': False},
#    {'station_id': '392',
#     'num_bikes_available': 29,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 4,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826365,
#     'eightd_has_available_keys': False},
#    {'station_id': '393',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 35,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825154,
#     'eightd_has_available_keys': False},
#    {'station_id': '394',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826175,
#     'eightd_has_available_keys': False},
#    {'station_id': '396',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825992,
#     'eightd_has_available_keys': False},
#    {'station_id': '397',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826222,
#     'eightd_has_available_keys': False},
#    {'station_id': '398',
#     'num_bikes_available': 23,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823076,
#     'eightd_has_available_keys': False},
#    {'station_id': '399',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824968,
#     'eightd_has_available_keys': False},
#    {'station_id': '400',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
# ...
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825042,
#     'eightd_has_available_keys': False},
#    {'station_id': '3862',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796132,
#     'eightd_has_available_keys': False},
#    {'station_id': '3863',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582811690,
#     'eightd_has_available_keys': False},
#    {'station_id': '3864',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796099,
#     'eightd_has_available_keys': False},
#    {'station_id': '3865',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820383,
#     'eightd_has_available_keys': False},
#    {'station_id': '3866',
#     'num_bikes_available': 5,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820256,
#     'eightd_has_available_keys': False},
#    {'station_id': '3867',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796116,
#     'eightd_has_available_keys': False},
#    {'station_id': '3868',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582804627,
#     'eightd_has_available_keys': False},
#    {'station_id': '3869',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582795991,
#     'eightd_has_available_keys': False},
#    {'station_id': '3870',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820228,
#     'eightd_has_available_keys': False},
#    {'station_id': '3871',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582795962,
#     'eightd_has_available_keys': False},
#    {'station_id': '3872',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797296,
#     'eightd_has_available_keys': False},
#    {'station_id': '3873',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797162,
#     'eightd_has_available_keys': False},
#    {'station_id': '3874',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813690,
#     'eightd_has_available_keys': False},
#    {'station_id': '3875',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797310,
#     'eightd_has_available_keys': False},
#    {'station_id': '3876',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582820632,
#     'eightd_has_available_keys': False},
#    {'station_id': '3877',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582813889,
#     'eightd_has_available_keys': False},
#    {'station_id': '3878',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796111,
#     'eightd_has_available_keys': False},
#    {'station_id': '3879',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824095,
#     'eightd_has_available_keys': False},
#    {'station_id': '3880',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582806787,
#     'eightd_has_available_keys': False},
#    {'station_id': '3881',
#     'num_bikes_available': 27,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823794,
#     'eightd_has_available_keys': False},
#    {'station_id': '3882',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823267,
#     'eightd_has_available_keys': False},
#    {'station_id': '3883',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796147,
#     'eightd_has_available_keys': False},
#    {'station_id': '3884',
#     'num_bikes_available': 6,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797278,
#     'eightd_has_available_keys': False},
#    {'station_id': '3885',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797228,
#     'eightd_has_available_keys': False},
#    {'station_id': '3886',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582809971,
#     'eightd_has_available_keys': False},
#    {'station_id': '3887',
#     'num_bikes_available': 2,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797158,
#     'eightd_has_available_keys': False},
#    {'station_id': '3888',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797159,
#     'eightd_has_available_keys': False},
#    {'station_id': '3890',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582816742,
#     'eightd_has_available_keys': False},
#    {'station_id': '3891',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796066,
#     'eightd_has_available_keys': False},
#    {'station_id': '3892',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582808167,
#     'eightd_has_available_keys': False},
#    {'station_id': '3893',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582812122,
#     'eightd_has_available_keys': False},
#    {'station_id': '3895',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 25,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582796035,
#     'eightd_has_available_keys': False},
#    {'station_id': '3896',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582819626,
#     'eightd_has_available_keys': False},
#    {'station_id': '3897',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582798357,
#     'eightd_has_available_keys': False},
#    {'station_id': '3898',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 49,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825733,
#     'eightd_has_available_keys': False},
#    {'station_id': '3899',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826098,
#     'eightd_has_available_keys': False},
#    {'station_id': '3900',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 29,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582823837,
#     'eightd_has_available_keys': False},
#    {'station_id': '3901',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797174,
#     'eightd_has_available_keys': False},
#    {'station_id': '3902',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797191,
#     'eightd_has_available_keys': False},
#    {'station_id': '3903',
#     'num_bikes_available': 4,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797327,
#     'eightd_has_available_keys': False},
#    {'station_id': '3905',
#     'num_bikes_available': 22,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826282,
#     'eightd_has_available_keys': False},
#    {'station_id': '3907',
#     'num_bikes_available': 1,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826219,
#     'eightd_has_available_keys': False},
#    {'station_id': '3909',
#     'num_bikes_available': 3,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582819490,
#     'eightd_has_available_keys': False},
#    {'station_id': '3910',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582797296,
#     'eightd_has_available_keys': False},
#    {'station_id': '3911',
#     'num_bikes_available': 9,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582824679,
#     'eightd_has_available_keys': False},
#    {'station_id': '3913',
#     'num_bikes_available': 19,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582783965,
#     'eightd_has_available_keys': False},
#    {'station_id': '3914',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 39,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582814909,
#     'eightd_has_available_keys': False},
#    {'station_id': '3916',
#     'num_bikes_available': 33,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 1,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826079,
#     'eightd_has_available_keys': True},
#    {'station_id': '3917',
#     'num_bikes_available': 7,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 24,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582826096,
#     'eightd_has_available_keys': False},
#    {'station_id': '3918',
#     'num_bikes_available': 0,
#     'num_ebikes_available': 0,
#     'num_bikes_disabled': 0,
#     'num_docks_available': 30,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1582825856,
#     'eightd_has_available_keys': False}]}}

# %%
# Convert the data into a Pandas dataframe:
station_status_df = pd.DataFrame(station_status_data['data']['stations'])
station_status_df.head()
# Out:
#   station_id  num_bikes_available  num_ebikes_available  num_bikes_disabled  \
# 0        304                   10                     1                   1
# 1        367                    5                     0                   0
# 2        402                   10                     0                   0
# 3       3443                    3                     0                   1
# 4         72                   44                     0                   0
#
#    num_docks_available  num_docks_disabled  is_installed  is_renting  \
# 0                   22                   0             1           1
# 1                   29                   0             1           1
# 2                   29                   0             1           1
# 3                   37                   0             1           1
# 4                   11                   0             1           1
#
#    is_returning  last_reported  eightd_has_available_keys  \
# 0             0     1582825054                       True
# 1             0     1582826089                      False
# 2             0     1582826401                      False
# 3             0     1582826174                      False
# 4             1     1582825850                      False
#
#                      eightd_active_station_services
# 0  [{'id': 'a58d9e34-2f28-40eb-b4a6-c8c01375657a'}]
# 1  [{'id': '2d9a5c9e-50e0-4aed-a63b-91ca81e7d2c0'}]
# 2  [{'id': '37a1ae1b-3dd6-4876-8c57-572aaac97981'}]
# 3  [{'id': '286d75b2-088f-4a79-bf7d-223928be711c'}]
# 4                                               NaN

# %% [markdown]
# ---
#
# ## 3.  Import Trip Data (from .csv)
# - We'll create a pandas dataframe from the data.
# - See https://s3.amazonaws.com/tripdata/index.html for available datasets.

# %%
# I just randomly grabbed this file:
bike_trips_df = pd.read_csv('202001-citibike-tripdata.csv')

# %%
# bike_trips_df.columns

# Using `list()` formats things a little better:
list(bike_trips_df.columns)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %% [markdown]
# ---
#
# ## Create a VeRoViz "nodes" Dataframe
# - We'll populate this with data from Station Info and Station Status
# - We'll also hard-code some columns

# %%
nodes = vrv.initDataframe('nodes')

# %%
# Here are the columns we'll need to populate:
#list(nodes.columns)

# %%
# Here are the columns from our "Station Info":
#list(station_info_df.columns)

# %%
# An example to show the syntax for displaying 2 particular columns from a df:
#station_info_df[['lat', 'lon']].head()

# %% [markdown]
# ---
# # Create the nodes to be passed to veroviz and Cesium
#
# ## Color-code the nodes based on Station STATUS.  For example:
#  - green  --> bikes and docks are available
#  - red    --> no bikes available
#  - yellow --> no docks available
#  - black --> avoid this station completely

# %%
# Convert the station status data into a Pandas dataframe:
station_status_df = pd.DataFrame(station_status_data['data']['stations'])
#Create a new column for leafletColor and cesiumColor 
    #-automatically populated as green for all stations
    #-later will represent all completely open stations (pick up and drop off)
station_status_df['leafletColor'] = 'green'
station_status_df['cesiumColor'] = 'Cesium.Color.GREEN'
#station_status_df

#Red if no bikes are available
#uses "is_renting"
station_status_df.loc[(station_status_df['is_renting']==0), 'leafletColor'] = 'red'
station_status_df.loc[(station_status_df['is_renting']==0), 'cesiumColor'] = 'Cesium.Color.RED'

#Orange (Yellow) if no bikes are available
#uses "is_returning"
station_status_df.loc[(station_status_df['is_returning']==0), 'leafletColor'] = 'orange'
station_status_df.loc[(station_status_df['is_returning']==0), 'cesiumColor'] = 'Cesium.Color.ORANGE'

#Black if station is not accessible (Avoid this station, we cannot rent or return)
#uses "is_renting" and "is_returing"
station_status_df.loc[(station_status_df['is_returning']==0) & (station_status_df['is_renting']==0), 'leafletColor'] = 'black'
station_status_df.loc[(station_status_df['is_returning']==0) & (station_status_df['is_renting']==0), 'cesiumColor'] = 'Cesium.Color.BLACK'

#Test to see if there are any 'color' stations
#station_status_df.loc[station_status_df.leafletColor=='orange']
#Show the dataframe
#station_status_df

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes = vrv.initDataframe('nodes')

# Now, copy the relevant columns from our Station Info dataframe:
# NOTE: We were getting some size mis-match errors until we copied 
#       just a single column first.  
nodes['id'] = station_info_df['station_id'].values
nodes[['id', 'lat', 'lon', 'nodeName']] = station_info_df[['station_id', 'lat', 'lon', 'name']].values
nodes[['leafletIconText', 'cesiumIconText']] = station_info_df[['name', 'station_id']].values
nodes[['leafletColor', 'cesiumColor']] = station_status_df[['leafletColor', 'cesiumColor']].values


# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes.loc[:,'altMeters'] = 0
nodes.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'CitiBikeStation',  'fa',                'bicycle']
nodes.loc[:,['cesiumIconType']] = ['pin']

# %%
# Show all of the nodes on a Leaflet map:
vrv.createLeaflet(nodes=nodes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ## Create a VeRoViz "assignments" Dataframe
# - We'll populate this with trip data
# - We'll also hard-code some columns

# %%
# Initialize an empty "assignments" dataframe:
assignments = vrv.initDataframe('assignments')
#assignments.info()

# %% [markdown]
# ### Here's the plan:
# - These columns will come directly from bike trip data:
#     - `objectID` (from `bikeid`)
#     - `startLat` and `startLon` (from `start station latitude` and `start station longitude`)
#     - `endLat` and `endLon` (from `end station latitude` and `end station longitude`)
# - These columns will need to be calculated:
#     - `startTimeSec` (from `starttime`, but converted to "seconds since the first event")
#     - `endTimeSec`   (from `starttime` and `tripduration`, or `starttime` and `stoptime`)
#     - We'll create some new columns in `bike_trips_df` to hold our calculations.  Then we'll copy these calculated columns into our assignments dataframe.
# - This column will need to be auto generated:
#     - `odID` (each origin/destination pair should get a unique integer)
# - The remaining columns will be hard-coded (for now)

# %%
# What is the first start time in our bike_trips_df?
min(bike_trips_df['starttime'])
# Out:
# '2020-01-01 00:00:55.3900'

# %%
# Add a new column to bike_trips_df...

# This next command will produce a "timestamp" (days HH:MM:SS.ms) 
# showing the time since the first observed `starttime`:
bike_trips_df['timeAfterStart'] = pd.to_datetime(bike_trips_df['starttime']) - \
                                  pd.to_datetime(min(bike_trips_df['starttime']))

# Now, convert this to a decimal number of seconds:
bike_trips_df['timeAfterStart'] = bike_trips_df['timeAfterStart'].dt.total_seconds().astype(int)

bike_trips_df['timeAfterStart'].head()
# Out:
# 0     0
# 1    12
# 2    46
# 3    50
# 4    50
# Name: timeAfterStart, dtype: int32

# %%
# Just for fun, here's the time differences between start/stop times:
pd.to_datetime(bike_trips_df['stoptime']) - pd.to_datetime(bike_trips_df['starttime'])
# Out:
# 0         00:13:09.757000
# 1         00:25:41.076000
# 2         00:24:24.871000
# 3         00:09:52.594000
# 4         00:11:42.452000
#                 ...
# 1240591   00:26:27.607000
# 1240592   00:03:42.831000
# 1240593   00:02:43.862000
# 1240594   00:05:27.148000
# 1240595   00:08:04.146000
# Length: 1240596, dtype: timedelta64[ns]

# %%
# In one cell, we'll create our assignments dataframe.

# Make sure we're starting with an empty dataframe:
assignments = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignments['objectID'] = bike_trips_df['bikeid']
assignments[['startLat', 'startLon', 'endLat', 'endLon']] = bike_trips_df[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignments['startTimeSec'] = bike_trips_df['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignments['endTimeSec'] = (bike_trips_df['timeAfterStart'] + bike_trips_df['tripduration']).values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignments.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                   'leafletColor', 'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                   'cesiumColor', 'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/car_blue.gltf', 100, 45, 0, 0, 
                   'blue', 2, 'solid', 0.8, False, 
                   'Cesium.Color.BLUE', 2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignments.loc[:,'odID'] = list(range(0, len(assignments)))

# %%
# Display what we've created:
assignments.head()
# Out:
#    odID  objectID                     modelFile  modelScale  modelMinPxSize  \
# 0     0     30326  veroviz/models/car_blue.gltf         100              45
# 1     1     17105  veroviz/models/car_blue.gltf         100              45
# 2     2     40177  veroviz/models/car_blue.gltf         100              45
# 3     3     27690  veroviz/models/car_blue.gltf         100              45
# 4     4     32583  veroviz/models/car_blue.gltf         100              45
#
#    startTimeSec   startLat   startLon  startAltMeters  endTimeSec  ...  \
# 0             0  40.732219 -73.981656               0         789  ...
# 1            12  40.661063 -73.979453               0        1553  ...
# 2            46  40.743227 -73.974498               0        1510  ...
# 3            50  40.736529 -74.006180               0         642  ...
# 4            50  40.694546 -73.958014               0         752  ...
#
#    endAltMeters  leafletColor  leafletWeight leafletStyle  leafletOpacity  \
# 0             0          blue              2        solid             0.8
# 1             0          blue              2        solid             0.8
# 2             0          blue              2        solid             0.8
# 3             0          blue              2        solid             0.8
# 4             0          blue              2        solid             0.8
#
#   useArrows        cesiumColor  cesiumWeight cesiumStyle  cesiumOpacity
# 0     False  Cesium.Color.BLUE             2       solid            0.7
# 1     False  Cesium.Color.BLUE             2       solid            0.7
# 2     False  Cesium.Color.BLUE             2       solid            0.7
# 3     False  Cesium.Color.BLUE             2       solid            0.7
# 4     False  Cesium.Color.BLUE             2       solid            0.7
#
# [5 rows x 22 columns]

# %% [markdown]
# ---
#
# ### Create a Leaflet map
# - We have a lot of bikes...let's just display one.

# %%
# FIXME

# Some (most?) of our bikes are being re-positioned by the CitiBike staff.
# We'll want to identify when this happens.

# One way to identify that a re-positioning has occurred is if 
# The start location for the next arc of a given bike does not 
# match the end location of the previous arc for this bike.

# We might also want to know when these activities occur.
# Is it only at night?  Do we have enough data to figure this out?

# OPTION 1: Use a "for" loop
# OPTION 2: Don't use a "for" loop
# Which option is faster?
# --> timeit()
#       import timeit or
#       %timeit   magic commands, only available in ipython
# --> current time - previous time

# Draw on (separate) leaflet map and a (separate) cesium movie, the repositioning of bikes
    #color the arcs differently on leaflet map? end time of previous station to start time of next station

#bike does not show up if it is static

#Use vrv.addStaticAssignment() to display stationary bikes. 
#This will show the bike slowly transitiioning between stations if the company is moving them.
#  ? Can we just append to end of assignments dataframe?
# ? If not, 

#Use the vrv filter option to create a map that only displays the manual moves

# %%
# I just randomly grabbed this file:
bike_trips_df = pd.read_csv('202001-citibike-tripdata.csv')
bike_trips_14530_df = pd.DataFrame(bike_trips_df[bike_trips_df['bikeid'] == 14530]).reset_index(drop = True)

# %% [markdown]
# ---
# # "Not a For loop" Option

# %%
#Duplicate the dataframe omitting the first row
B_bike_trips_14530_df = bike_trips_14530_df.loc[1:, :].reset_index(drop = True)
#B_bike_trips_14530_df[['start station latitude', 'start station longitude']]

#Create new columns in the original dataframe and populate them with the next start station to check for repositioning
bike_trips_14530_df['next start lat'] = 0
bike_trips_14530_df['next start lon'] = 0
bike_trips_14530_df['next start time'] = 0
bike_trips_14530_df['repositioning'] = 0
bike_trips_14530_df['leafletColor'] = 'blue'
bike_trips_14530_df['cesiumColor'] = 'Cesium.Color.BLUE'
bike_trips_14530_df['next start lat'] = B_bike_trips_14530_df['start station latitude']
bike_trips_14530_df['next start lon'] = B_bike_trips_14530_df['start station longitude']
bike_trips_14530_df['next start time'] = B_bike_trips_14530_df['starttime'] #for static assignment

# %%
#Calculate if repositioning happens
bike_trips_14530_df.loc[(bike_trips_14530_df['next start lat'] != bike_trips_14530_df['end station latitude']) & (bike_trips_14530_df['next start lon'] != bike_trips_14530_df['end station longitude']), 'repositioning'] = 1
bike_trips_14530_df.iloc[-1, bike_trips_14530_df.columns.get_loc('repositioning')] = 0 
bike_trips_14530_df.iloc[-1, bike_trips_14530_df.columns.get_loc('next start time')] = bike_trips_14530_df.iloc[-1, bike_trips_14530_df.columns.get_loc('stoptime')]
#bike_trips_14530_df.loc[bike_trips_14530_df['repositioning'] == 1]
bike_trips_14530_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            548  2020-01-02 09:25:11.9390  2020-01-02 09:34:20.3600
# 1           1061  2020-01-02 18:16:45.1630  2020-01-02 18:34:26.5780
# 2            400  2020-01-05 14:27:01.9750  2020-01-05 14:33:42.1210
# 3            301  2020-01-06 16:10:01.6600  2020-01-06 16:15:03.0080
# 4            167  2020-01-06 17:15:51.0260  2020-01-06 17:18:38.1240
# ..           ...                       ...                       ...
# 69          1689  2020-01-30 18:30:48.6870  2020-01-30 18:58:58.0690
# 70           388  2020-01-30 19:30:54.8530  2020-01-30 19:37:23.7710
# 71           884  2020-01-30 21:52:15.6920  2020-01-30 22:07:00.2830
# 72           515  2020-01-31 08:27:54.4500  2020-01-31 08:36:30.1120
# 73           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
#
#     start station id           start station name  start station latitude  \
# 0                261         Johnson St & Gold St               40.694749
# 1               2000     Front St & Washington St               40.702551
# 2               3414     Bergen St & Flatbush Ave               40.680945
# 3               3486    Schermerhorn St & Bond St               40.688417
# 4                241  DeKalb Ave & S Portland Ave               40.689810
# ..               ...                          ...                     ...
# 69               362           Broadway & W 37 St               40.751726
# 70               151     Cleveland Pl & Spring St               40.722104
# 71               311       Norfolk St & Broome St               40.717227
# 72               297              E 15 St & 3 Ave               40.734232
# 73               379              W 31 St & 7 Ave               40.749156
#
#     start station longitude  end station id             end station name  \
# 0                -73.983625            2000     Front St & Washington St
# 1                -73.989402            3414     Bergen St & Flatbush Ave
# 2                -73.975673            3486    Schermerhorn St & Bond St
# 3                -73.984517             241  DeKalb Ave & S Portland Ave
# 4                -73.974931             324      DeKalb Ave & Hudson Ave
# ..                      ...             ...                          ...
# 69               -73.987535             151     Cleveland Pl & Spring St
# 70               -73.997249             311       Norfolk St & Broome St
# 71               -73.988021             297              E 15 St & 3 Ave
# 72               -73.986923             379              W 31 St & 7 Ave
# 73               -73.991600             496              E 16 St & 5 Ave
#
#     end station latitude  ...  bikeid    usertype birth year  gender  \
# 0              40.702551  ...   14530  Subscriber       1987       1
# 1              40.680945  ...   14530  Subscriber       1992       1
# 2              40.688417  ...   14530    Customer       1969       0
# 3              40.689810  ...   14530  Subscriber       1985       1
# 4              40.689888  ...   14530  Subscriber       1998       1
# ..                   ...  ...     ...         ...        ...     ...
# 69             40.722104  ...   14530    Customer       1995       1
# 70             40.717227  ...   14530  Subscriber       1973       1
# 71             40.734232  ...   14530  Subscriber       1983       1
# 72             40.749156  ...   14530  Subscriber       1993       1
# 73             40.737262  ...   14530  Subscriber       1981       1
#
#     next start lat  next start lon           next start time repositioning  \
# 0        40.702551      -73.989402  2020-01-02 18:16:45.1630             0
# 1        40.680945      -73.975673  2020-01-05 14:27:01.9750             0
# 2        40.688417      -73.984517  2020-01-06 16:10:01.6600             0
# 3        40.689810      -73.974931  2020-01-06 17:15:51.0260             0
# 4        40.689888      -73.981013  2020-01-06 17:24:58.6320             0
# ..             ...             ...                       ...           ...
# 69       40.722104      -73.997249  2020-01-30 19:30:54.8530             0
# 70       40.717227      -73.988021  2020-01-30 21:52:15.6920             0
# 71       40.734232      -73.986923  2020-01-31 08:27:54.4500             0
# 72       40.749156      -73.991600  2020-01-31 08:41:55.1210             0
# 73             NaN             NaN  2020-01-31 08:50:44.3750             0
#
#     leafletColor        cesiumColor
# 0           blue  Cesium.Color.BLUE
# 1           blue  Cesium.Color.BLUE
# 2           blue  Cesium.Color.BLUE
# 3           blue  Cesium.Color.BLUE
# 4           blue  Cesium.Color.BLUE
# ..           ...                ...
# 69          blue  Cesium.Color.BLUE
# 70          blue  Cesium.Color.BLUE
# 71          blue  Cesium.Color.BLUE
# 72          blue  Cesium.Color.BLUE
# 73          blue  Cesium.Color.BLUE
#
# [74 rows x 21 columns]

# %%
#appending a new row to show the movement of bikes
for i in range(len(bike_trips_14530_df)-1):
    if bike_trips_14530_df['repositioning'][i] == 1:
        data = [{'tripduration':28800 ,
                 'starttime':bike_trips_14530_df['stoptime'][i], 
                 'stoptime':bike_trips_14530_df['starttime'][i+1], 
                 'start station id':bike_trips_14530_df['end station id'][i], 
                 'start station name': None, 
                 'start station latitude':bike_trips_14530_df['end station latitude'][i],
                 'start station longitude':bike_trips_14530_df['end station longitude'][i], 
                 'end station id':bike_trips_14530_df['start station id'][i+1], 
                 'end station name':None, 
                 'end station latitude':bike_trips_14530_df['next start lat'][i], 
                 'end station longitude': bike_trips_14530_df['next start lon'][i], 
                 'bikeid':bike_trips_14530_df['bikeid'][i],  
                 'usertype':None, 
                 'birth year':None, 
                 'gender':None, 
                 'timeAfterStart':bike_trips_14530_df['tripduration'][i+1], 
                 'leafletColor':'red', 
                 'cesiumColor': 'Cesium.Color.RED', 
                 'capacity':None}]
        bike_trips_14530_df = bike_trips_14530_df.append(data)
bike_trips_14530_df = bike_trips_14530_df.reset_index(drop = True)
bike_trips_14530_df
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            548  2020-01-02 09:25:11.9390  2020-01-02 09:34:20.3600
# 1           1061  2020-01-02 18:16:45.1630  2020-01-02 18:34:26.5780
# 2            400  2020-01-05 14:27:01.9750  2020-01-05 14:33:42.1210
# 3            301  2020-01-06 16:10:01.6600  2020-01-06 16:15:03.0080
# 4            167  2020-01-06 17:15:51.0260  2020-01-06 17:18:38.1240
# ..           ...                       ...                       ...
# 73           529  2020-01-31 08:41:55.1210  2020-01-31 08:50:44.3750
# 74         28800  2020-01-06 21:59:37.9540  2020-01-07 13:23:12.3180
# 75         28800  2020-01-16 09:48:57.9800  2020-01-16 12:00:41.2330
# 76         28800  2020-01-16 12:05:29.6630  2020-01-17 09:15:27.4700
# 77         28800  2020-01-17 17:13:53.6720  2020-01-19 14:50:54.0040
#
#     start station id           start station name  start station latitude  \
# 0                261         Johnson St & Gold St               40.694749
# 1               2000     Front St & Washington St               40.702551
# 2               3414     Bergen St & Flatbush Ave               40.680945
# 3               3486    Schermerhorn St & Bond St               40.688417
# 4                241  DeKalb Ave & S Portland Ave               40.689810
# ..               ...                          ...                     ...
# 73               379              W 31 St & 7 Ave               40.749156
# 74              3232                         None               40.689622
# 75               280                         None               40.733320
# 76              3812                         None               40.734814
# 77               509                         None               40.745497
#
#     start station longitude  end station id             end station name  \
# 0                -73.983625            2000     Front St & Washington St
# 1                -73.989402            3414     Bergen St & Flatbush Ave
# 2                -73.975673            3486    Schermerhorn St & Bond St
# 3                -73.984517             241  DeKalb Ave & S Portland Ave
# 4                -73.974931             324      DeKalb Ave & Hudson Ave
# ..                      ...             ...                          ...
# 73               -73.991600             496              E 16 St & 5 Ave
# 74               -73.983043            3377                         None
# 75               -73.995101             326                         None
# 76               -73.992085             504                         None
# 77               -74.001971            3724                         None
#
#     end station latitude  ...  birth year  gender next start lat  \
# 0              40.702551  ...        1987       1      40.702551
# 1              40.680945  ...        1992       1      40.680945
# 2              40.688417  ...        1969       0      40.688417
# 3              40.689810  ...        1985       1      40.689810
# 4              40.689888  ...        1998       1      40.689888
# ..                   ...  ...         ...     ...            ...
# 73             40.737262  ...        1981       1            NaN
# 74             40.678612  ...        None    None            NaN
# 75             40.729538  ...        None    None            NaN
# 76             40.732219  ...        None    None            NaN
# 77             40.766741  ...        None    None            NaN
#
#    next start lon           next start time  repositioning  leafletColor  \
# 0      -73.989402  2020-01-02 18:16:45.1630            0.0          blue
# 1      -73.975673  2020-01-05 14:27:01.9750            0.0          blue
# 2      -73.984517  2020-01-06 16:10:01.6600            0.0          blue
# 3      -73.974931  2020-01-06 17:15:51.0260            0.0          blue
# 4      -73.981013  2020-01-06 17:24:58.6320            0.0          blue
# ..            ...                       ...            ...           ...
# 73            NaN  2020-01-31 08:50:44.3750            0.0          blue
# 74            NaN                       NaN            NaN           red
# 75            NaN                       NaN            NaN           red
# 76            NaN                       NaN            NaN           red
# 77            NaN                       NaN            NaN           red
#
#           cesiumColor  timeAfterStart capacity
# 0   Cesium.Color.BLUE             NaN      NaN
# 1   Cesium.Color.BLUE             NaN      NaN
# 2   Cesium.Color.BLUE             NaN      NaN
# 3   Cesium.Color.BLUE             NaN      NaN
# 4   Cesium.Color.BLUE             NaN      NaN
# ..                ...             ...      ...
# 73  Cesium.Color.BLUE             NaN      NaN
# 74   Cesium.Color.RED           370.0     None
# 75   Cesium.Color.RED           288.0     None
# 76   Cesium.Color.RED           377.0     None
# 77   Cesium.Color.RED           322.0     None
#
# [78 rows x 23 columns]

# %%
#bike_trips_14530_df = bike_trips_14530_df.reset_index(drop = True)
#bike_trips_14530_df

# %%
# Initialize an empty "assignments" dataframe:
assignments14530 = vrv.initDataframe('assignments')

# %%
# In one cell, we'll create our assignments dataframe.

# Make sure we're starting with an empty dataframe:
assignments14530 = vrv.initDataframe('assignments')

# Copy over the static values.
# We'll start by copying a single column, to avoid the size mis-match issue:
assignments14530['objectID'] = bike_trips_14530_df['bikeid']
assignments14530[['leafletColor', 'cesiumColor']] = bike_trips_14530_df[['leafletColor', 'cesiumColor']].values
assignments14530[['startLat', 'startLon', 'endLat', 'endLon']] = bike_trips_14530_df[['start station latitude', 
                                                                          'start station longitude',
                                                                          'end station latitude',
                                                                          'end station longitude']].values

# Copy our new calculated column:
assignments14530['startTimeSec'] = bike_trips_14530_df['timeAfterStart'].values

# Use the calculated column and tripduration to get the end time (in seconds):
assignments14530['endTimeSec'] = (bike_trips_14530_df['timeAfterStart'] + bike_trips_14530_df['tripduration']).values

# Fill in the rest of our assignments df with some hard-coded values:
# (we'll probably want to revisit this later)
assignments14530.loc[:,['modelFile', 'modelScale', 'modelMinPxSize', 'startAltMeters', 'endAltMeters', 
                    'leafletWeight', 'leafletStyle', 'leafletOpacity', 'useArrows',
                    'cesiumWeight', 'cesiumStyle', 'cesiumOpacity']] = \
                  ['veroviz/models/car_blue.gltf', 100, 45, 0, 0, 
                    2, 'solid', 0.8, False, 
                    2, 'solid', 0.7]

# Finally (for now), let's generate a unique odID value for each row.
# This will make sense only if we assume that each row corresponds to a specific
# O/D pair.  Conversely, if we have turn-by-turn arcs, we'll need to group
# multiple rows into the same O/D pair.  We'll tackle that case if/when 
# we encounter it.
assignments14530.loc[:,'odID'] = list(range(0, len(assignments14530)))

# %%
vrv.createLeaflet(arcs=assignments14530)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vrv.addStaticAssignment?

# %%
'''#Add static assignments so the bike does not disappear when docked in a station
#initialize a static assignments dataframe

static_assignment = vrv.addStaticAssignment(
    initAssignments=None,
    odID=1,
    objectID=None,
    modelFile=None,
    modelScale=100,
    modelMinPxSize=75,
    loc=None,
    startTimeSec=None,
    endTimeSec=None,
)
)
#vrv.addStaticAssignment''';

# %% [markdown]
# ---
#
# ### Create a Cesium movie for one bike

# %%
# Use this command to get documentation on the `createCesium()` function:
#vrv.createCesium?

# %%
'''
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments[assignments['objectID'] == 14530],
    nodes       = nodes,
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
''';

# %%
# FIXME

# The Cesium movie is cluttered with all of our station markers.
# It would be better to only include the markers that are actually relevant 
# to our given bike.

# Fortunately, our bike trips df contains the station IDs.
# We just need to get a list of unique IDs, and then 
# pass to createCesium only the subset of nodes corresponding to these IDs.

# %%
# Let's go ahead and re-initialize an empty dataframe within this cell:
nodes1 = vrv.initDataframe('nodes')


# Include the nodes that are traveled to by this bike
nodes1['id'] = bike_trips_df['bikeid'].values
nodes1[['id', 'lat', 'lon', 'nodeName']] = bike_trips_df[['bikeid', 'start station latitude', 'start station longitude', 'start station id']].values
nodes1[['leafletIconText', 'cesiumIconText']] = bike_trips_df[['start station id', 'start station id']].values


# Finally, we'll fill in the rest of our nodes dataframe with some hard-coded/constant values:
nodes1.loc[:,'altMeters'] = 0
nodes1.loc[:,['nodeType', 'leafletIconPrefix', 'leafletIconType']] = [
             'CitiBikeStation',  'fa',                'bicycle']
nodes1.loc[:,['cesiumIconType']] = ['pin']
nodes1.loc[:,['leafletColor', 'cesiumColor']] = ['blue', 'Cesium.Color.BLUE']

# %%
bike_trips_df.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 1240591          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 1240592           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 1240593           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 1240594           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 1240595           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id          start station name  start station latitude  \
# 1240591              3244      University Pl & E 8 St               40.731437
# 1240592               383  Greenwich Ave & Charles St               40.735238
# 1240593               150           E 2 St & Avenue C               40.720874
# 1240594               483             E 12 St & 3 Ave               40.732233
# 1240595               327    Vesey Pl & River Terrace               40.715338
#
#          start station longitude  end station id            end station name  \
# 1240591               -73.994903            3092           Berry St & N 8 St
# 1240592               -74.000271             383  Greenwich Ave & Charles St
# 1240593               -73.980858             411           E 6 St & Avenue D
# 1240594               -73.988900            3718          E 11 St & Avenue B
# 1240595               -74.016584             534     Water - Whitehall Plaza
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 1240591             40.719009             -73.958525   40662  Subscriber
# 1240592             40.735238             -74.000271   28722  Subscriber
# 1240593             40.722281             -73.976687   32530  Subscriber
# 1240594             40.727464             -73.979504   15314    Customer
# 1240595             40.702551             -74.012723   30947  Subscriber
#
#          birth year  gender
# 1240591        1990       1
# 1240592        1983       1
# 1240593        1958       2
# 1240594        1994       1
# 1240595        1987       1

# %%
# Show all of the nodes on a Leaflet map:
vrv.createLeaflet(nodes=nodes1[nodes1['id'] == 14530])

#vrv.createLeaflet(arcs=assignments[assignments['objectID'] == 14530])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# startDate: Format is "YYYY-MM-DD"
startDate = pd.to_datetime(min(bike_trips_14530_df['starttime'])).strftime('%Y-%m-%d')

# startTime: Format is "HH:MM:SS"
startTime = pd.to_datetime(min(bike_trips_14530_df['starttime'])).strftime('%H:%M:%S')

vrv.createCesium(
    assignments = assignments[assignments['objectID'] == 14530],
    nodes       = nodes1[nodes1['id'] == 14530],
    startDate   = startDate,
    startTime   = startTime,
    cesiumDir   = os.environ['CESIUMDIR'],
    problemDir  = 'IE_670/citibike_example')
# Out:
# Message: File selector was written to C:/Cesium/IE_670/citibike_example/;IE_670;citibike_example.vrv ...
# Message: Configs were written to C:/Cesium/IE_670/citibike_example/config.js ...
# Message: Nodes were written to C:/Cesium/IE_670/citibike_example/displayNodes.js ...
# Message: Assignments (.js) were written to C:/Cesium/IE_670/citibike_example/displayPaths.js ...
# Message: Assignments (.czml) were written to C:/Cesium/IE_670/citibike_example/routes.czml ...

# %% [markdown]
# ---
#
# #### Playing around with dates/times
# - Here's some code related to formatting dates/times.  There might be something useful here in the future...

# %%
#pd.to_datetime(bike_trips_df['starttime']).dt.date
# Out:
# 0          2020-01-01
# 1          2020-01-01
# 2          2020-01-01
# 3          2020-01-01
# 4          2020-01-01
#               ...
# 1240591    2020-01-31
# 1240592    2020-01-31
# 1240593    2020-01-31
# 1240594    2020-01-31
# 1240595    2020-01-31
# Name: starttime, Length: 1240596, dtype: object

# %%
#pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%Y-%m-%d')
# Out:
# '2020-01-01'

# %%
#pd.to_datetime(min(bike_trips_df['starttime'])).strftime('%H:%M:%S')
# Out:
# '00:00:55'

# %% [markdown]
# ---
#
# ### NYC Subway Stations
#
# - A list of subway stations may be found here:
#     - http://web.mta.info/developers/data/nyct/subway/Stations.csv
#
# - Other links:
#     - http://web.mta.info/developers/index.html
#     - http://datamine.mta.info/list-of-feeds
#
# Ideas:
# - For a given location, find the nearest subway station.
# - For a given destination, find the nearest **available** CitiBike station.
# - For a given O/D pair, determine the best combination of subways/bikes to use.
